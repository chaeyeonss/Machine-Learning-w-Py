# %% [markdown]
# ### 분류 알고리즘
# 분류(Classification)는 학습 데이터로 주어진 데이터의 피처와 레이블 값(결정 값, 클래스 값)을 머신러닝 알고리즘으로 학습해 모델을 생성하고, 그 모델에 새로운 데이터 값이 주어졌을 때 미지의 레이블 값을 예측하는 것입니다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ※ 회귀 알고리즘 중에 분류가 되는 알고리즘이 있다.
# <br>※ 앙상블은 결정 트리를 기반으로 한다.

# %% [markdown]
# ### 결정 트리와 앙상블
# - 결정 트리
#   <br>매우 쉽고 유연하게 적용될 수 있는 알고리즘. 데이터의 스케일링이나 정규화 등의 사전 가공의 **영향이 매우 적다.** 하지만 예측 성능을 향상시키기 위해 **복잡한 규칙 구조**를 가져야 하며, 이로 인한 **과적합(Overfitting)**이 발생해 반대로 예측 성능이 저하될 수 있다는 단점 有.
#   <br>**※ 과적합:** 너무 자세한 조건들로 데이터를 분류해 예상치 못한 튀는 데이터를 받았을 때는 올바른 예측을 할 수 없어 성능이 확 떨어진다.
#
#
# - 이러한 단점이 **앙상블 기법에서는 장점으로 적용**한다. 매우 많은 여러 개의 '예측 성능이 상대적으로 떨어지는 학습 알고리즘'을 결합해 확률적 보완과 오류가 발생한 부분에 대한 가중치를 계속 업데이트하면서 예측 성능을 향상시키는데, 결정 트리가 그런 알고리즘 중 하나이다. (GBM, XGBoost, LightGBM 등)

# %% [markdown]
# ## 결정 트리
# - 데이터에 있는 규칙을 학습을 통해 자동으로 찾아내 트리 기반의 분류 규칙을 만듦. (if-else 기반 규칙)
#
#   → **데이터의 어떤 기준을 바탕으로 규칙을 만드느냐**에 따라 알고리즘의 성능을 크게 좌우
# ![image.png](attachment:image.png)
# ※ 해당하는 데이터를 찾으면 그 그룹은 리프 노드로 결정

# %% [markdown]
# ### 트리 분할을 위한 데이터의 균일도
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### **정보 균일도 측정 방법**
# * **정보 이득(Information Gain)**
#   <br>**엔트로피**(주어진 데이터 집합의 혼잡도) 개념 기반.
#   <br>서로 다른 값이 섞여 있으면 엔트로피가 높고, 같은 값이 섞여 있으면 엔트로피가 낮다.
#     - 정보 이득 지수: 1 - (엔트로피 지수)
#     - 결정 트리는 정보 이득 지수로 분할 기준을 결정한다.
#       <br>정보 이득이 높은 속성(엔트로피가 낮은 속성)을 기준으로 분할
#
# * **지니 계수**
#   <br>(@경제학) 불평등 지수를 나타낼 때 사용하는 계수
#   - 0이 가장 평등하고 1로 갈수록 불평등
#   - (@머신러닝) 지니 계수가 낮을수록 데이터 균일도가 높음
#     <br>계수가 낮은 속성을 기준으로 분할

# %% [markdown]
# ### 결정 트리 규칙 노트 생성 프로세스
# ![image.png](attachment:image.png)
